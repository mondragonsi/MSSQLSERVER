-- %% [markdown]
-- **BE DATA MASTER**

-- %%
use AdventureWorks2019
GO
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.002

-- %%
use AdventureWorks2019
GO

BEGIN TRANSACTION
    UPDATE Person.Person SET FirstName = 'Xuxa'
    WHERE BusinessEntityID = 10

SELECT * from Person.Person WHERE BusinessEntityID = 10
-- Out:
-- Commands completed successfully.
-- (1 row affected)
-- (1 row affected)
-- Total execution time: 00:00:00.087
-- <table><tr><th>BusinessEntityID</th><th>PersonType</th><th>NameStyle</th><th>Title</th><th>FirstName</th><th>MiddleName</th><th>LastName</th><th>Suffix</th><th>EmailPromotion</th><th>AdditionalContactInfo</th><th>Demographics</th><th>rowguid</th><th>ModifiedDate</th></tr><tr><td>10</td><td>EM</td><td>0</td><td>NULL</td><td>Xuxa</td><td>NULL</td><td>Raheem</td><td>NULL</td><td>2</td><td>NULL</td><td>&lt;IndividualSurvey xmlns=&quot;http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey&quot;&gt;&lt;TotalPurchaseYTD&gt;0&lt;/TotalPurchaseYTD&gt;&lt;/IndividualSurvey&gt;</td><td>ca2c740e-75b2-420c-9d4b-e3cbc6609604</td><td>2009-04-26 00:00:00.000</td></tr></table>

-- %%
SELECT * from Person.Person
where BusinessEntityId = 10
GO
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.007
-- <table><tr><th>BusinessEntityID</th><th>PersonType</th><th>NameStyle</th><th>Title</th><th>FirstName</th><th>MiddleName</th><th>LastName</th><th>Suffix</th><th>EmailPromotion</th><th>AdditionalContactInfo</th><th>Demographics</th><th>rowguid</th><th>ModifiedDate</th></tr><tr><td>10</td><td>EM</td><td>0</td><td>NULL</td><td>Xuxa</td><td>NULL</td><td>Raheem</td><td>NULL</td><td>2</td><td>NULL</td><td>&lt;IndividualSurvey xmlns=&quot;http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/IndividualSurvey&quot;&gt;&lt;TotalPurchaseYTD&gt;0&lt;/TotalPurchaseYTD&gt;&lt;/IndividualSurvey&gt;</td><td>ca2c740e-75b2-420c-9d4b-e3cbc6609604</td><td>2009-04-26 00:00:00.000</td></tr></table>

-- %% [markdown]
-- #
--
-- # **COMO Funciona uma Query no Engine do SQL Server?**
--
-- O SQL Server usa a camada de PROTOCOLO SNI (SQL Server Network INTERFACE). Os protocolos usados sao
--
-- > \-Shared Memory
-- >
-- > \- Named Pipes (usado para LAN)
-- >
-- > \- TCP/IP
-- >
-- > Posso colocar mais de uma port nas configuracoes usando a sintax: \[6550\],\[6551\]
-- >
-- > Pode-ser usar Alias tambem!
-- >
-- > Alias e criado no Servidor de Aplicacao! Nao no Servidor de Banco!
-- >
-- > TDS eh o pacote de comunicacao entre o SQL Server e Cliente.
-- >
-- > **CONTA DAC!!!!!**
-- >
-- > Entrada pela portas dos fundos do SQL Server
-- >
-- > Pequeno espaco de memoria para poder accessar!
-- >
-- > End-Point reservado!
-- >
-- > Dedicated Admin Account:
-- >
-- >
-- >
-- > Connectando com a conta DAC:
-- >
-- > ![](data:image/png;base64,...)
-- >
-- > BROWSER para poder usar o DAC!
-- >
-- > ![](data:image/png;base64,...)
-- >
-- > PARSER = verifica sintax
-- >
-- >
-- >
-- >

-- %%
--Verifica cached plans (Queremos a coluna usecounts alta)
select * from sys.dm_exec_cached_plans
order by usecounts DESC
-- Out:
-- (167 rows affected)
-- Total execution time: 00:00:00.013
-- ...
